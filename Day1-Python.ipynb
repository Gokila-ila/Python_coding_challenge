# %% [markdown]
# # PYTHON Coding Challenge
# ##DAY1-Introduction to Programming Languages and Python

# %%
#Students Profile creator
#Tasks:
## 1.Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.

student1_name="Alfa"
student1_age='16'
student1_subjects=["SQL","Python","Analytics"]
student2_name="Beta"
student2_age='15'
student2_subjects=["Excel,PowerBI,SQL"]

# %%
## 2.Display the student’s information in a user-friendly format.

print("Student1 Name: ",student1_name)
print("Age:",student1_age)
print("Favourite Subjects: ",student1_subjects)
print("Student2 Name: ",student2_name)
print("Age: ",student2_age)
print("Favourite subjects:",student2_subjects)
# Out:
# Student1 Name:  Alfa
# Age: 16
# Favourite Subjects:  ['SQL', 'Python', 'Analytics']
# Student2 Name:  Beta
# Age:  15
# Favourite subjects: ['Excel,PowerBI,SQL']

# %%
## 3.Display the updated list of subjects.
student1_subjects.append("Tableau")
print("Updated list of subjects",student1_subjects)
# Out:
# Updated list of subjects ['SQL', 'Python', 'Analytics', 'Tableau']
